# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from db.connection import connect_mysql, connect_postgresql, connect_sqlite, connect_oracle, connect_sql_server
from agents.extraction_agent import ExtractionAgent

# %%
agent = ExtractionAgent("sql_server", "Jobz")

# tester extract_table
print("Test extract_table")
df = agent.extract_table("Entreprises")
print(df.head())

# tester extract_with_conditions
print("Test extract_with_conditions")
df2 = agent.extract_with_conditions("Entreprises", "salary > 3000")
print(df2.head())

# tester extract_columns_name
print("Test extract_columns_name")
cols = agent.extract_columns_name("Entreprises")
print(cols)

# tester extract_table_schema
print("Test extract_table_schema")
schema = agent.extract_table_schema("Entreprises")
print(schema)

# tester export csv
print("Test extract_table_to_csv")
agent.extract_table_to_csv("Entreprises", "Entreprises.csv")

print("All tests finished")
# Out:
# Test extract_table
# c:\Users\OMEN\Desktop\multiagent_data_platform\agents\extraction_agent.py:31: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   with self.engine.connect() as connection:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\OMEN\Desktop\multiagent_data_platform\venv\Lib\site-packages\sqlalchemy\engine\base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1414 try:
# -> 1415     meth = statement._execute_on_connection
#    1416 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[3], line 5
#       3 # tester extract_table
#       4 print("Test extract_table")
# ----> 5 df = agent.extract_table("Entreprises")
#       6 print(df.head())
#       8 # tester extract_with_conditions
#
# File c:\Users\OMEN\Desktop\multiagent_data_platform\agents\extraction_agent.py:43, in ExtractionAgent.extract_table(self, table_name)
#      36 def extract_table(self, table_name):
#      38     query = f"""
#      39     SELECT COLUMN_NAME, DATA_TYPE
#      40     FROM INFORMATION_SCHEMA.COLUMNS
#      41     WHERE TABLE_NAME = '{table_name}'
#      42     """
# ---> 43     return self.extract_data(query)
#
# File c:\Users\OMEN\Desktop\multiagent_data_platform\agents\extraction_agent.py:32, in ExtractionAgent.extract_data(self, query)
#      30 def extract_data(self, query):
#      31     with self.engine.connect() as connection:
# ---> 32         result = connection.execute(query)
#      33         df = pd.DataFrame(result.fetchall(), columns=result.keys())
#      34     return df
#
# File c:\Users\OMEN\Desktop\multiagent_data_platform\venv\Lib\site-packages\sqlalchemy\engine\base.py:1417, in Connection.execute(self, statement, parameters, execution_options)
#    1415     meth = statement._execute_on_connection
#    1416 except AttributeError as err:
# -> 1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
#    1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# ObjectNotExecutableError: Not an executable object: "\n        SELECT COLUMN_NAME, DATA_TYPE\n        FROM INFORMATION_SCHEMA.COLUMNS\n        WHERE TABLE_NAME = 'Entreprises'\n        "

# %%
from db.connection import connect_sql_server

engine = connect_sql_server("Jobz")

print(engine)
# Out:
# Engine(mssql+pyodbc://@DESKTOP-MEOKMIT\SQLEXPRESS/Jobz?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes)

# %%
import pandas as pd

df = pd.read_sql("SELECT TOP 5 * FROM Entreprises", engine)

print(df)
# Out:
#    Id      Nom       Secteur Description  \
# 0   1  hjfvfgn  Non spécifié     GUJGUJG
#
#                                                 Logo  \
# 0  /uploads/entreprises/f3c7af2a-afa5-455b-b4ff-3...
#
#                 DateCreation CreerPar  EstSupprime DateSuppression  \
# 0 2026-01-08 15:35:26.835947     None        False            None
#
#   SupprimerPar         Email                                    MotDePasse
# 0         None  cc@gmail.com  lfc7V2u0mRS2cNn+KrHVrpDt0co1Uuhg2WYvYHOafQg=
# c:\Users\OMEN\Desktop\multiagent_data_platform\venv\Lib\site-packages\pandas\io\sql.py:1649: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())
